# %%
from bs4 import BeautifulSoup as bs
import requests
from time import sleep
import pandas as pd

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'

# %%
def parse_hh(job, page):
    headers = {
        'User-Agent': user_agent
    }
    params = {'text': job, 'page': page}
    url = 'https://hh.ru/search/vacancy'
    response = requests.get(url, headers = headers, params = params)
    return response

# %%
def find_job(tag):
    title = tag.find('a', {'class':'serp-item__title'}).text
    link = tag.find('a', {'class':'serp-item__title'})['href']
    salary = tag.find('span', {'data-qa': 'vacancy-serp__vacancy-compensation'})
    if salary is not None:
        salary = salary.text
    else:
        salary = 'з/п не указана'
    return {'title': title, 'salary': salary, 'link': link}

# %%
def get_job_from_pages(job, number_of_pages):
    jobs_list = list()
    for page in range(number_of_pages):
        response = parse_hh(job, page)
        soup = bs(response.text, 'html.parser')
        serp_item_list = soup.find_all('div', {'class': 'serp-item'})
        for vacancy in serp_item_list:
            jobs_list.append(find_job(vacancy))
        sleep(1)
    return jobs_list

# %%
hh_list = get_job_from_pages('data science', 3)
hh_list
# Out:
# [{'title': 'NLP исследователь в группу AI в медицине Sber AI Lab',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73469286?from=vacancy_search_list&query=data+science'},
#  {'title': 'Python developer (Machine Learning Engineer)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73468878?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data engineer',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73471184?from=vacancy_search_list&query=data+science'},
#  {'title': 'Middle Data Science в лабораторию искусственного интеллекта Сбера',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/72747471?from=vacancy_search_list&query=data+science'},
#  {'title': 'NLP исследователь в группу AI в медицине Sber AI Lab',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/72798521?from=vacancy_search_list&query=data+science'},
#  {'title': 'Python developer (Machine Learning Engineer)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/72074865?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data engineer',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/72030869?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Scientist',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/69162481?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data scientist (Управление рисками корпоративных клиентов)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/72421275?from=vacancy_search_list&query=data+science'},
#  {'title': 'Middle Data Engineer',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73751663?from=vacancy_search_list&query=data+science'},
#  {'title': 'Специалист по углубленной аналитике данных (Data scientist)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/72920605?from=vacancy_search_list&query=data+science'},
#  {'title': 'Middle продуктовый аналитик для продукта Talantix',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/72468896?from=vacancy_search_list&query=data+science'},
#  {'title': 'Владелец моделей оценки рисков РБ',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73470798?from=vacancy_search_list&query=data+science'},
#  {'title': 'Владелец моделей оценки рисков РБ',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/72285480?from=vacancy_search_list&query=data+science'},
#  {'title': 'Head of Data Science',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/74150096?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Science (Компьютерное зрение)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/74149899?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Engineer',
#   'salary': 'от 300\u202f000 руб.',
#   'link': 'https://hh.ru/vacancy/74080731?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Engineer',
#   'salary': 'от 300\u202f000 руб.',
#   'link': 'https://hh.ru/vacancy/74080730?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Scientist',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/70243733?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Engineer',
#   'salary': 'от 230\u202f000 руб.',
#   'link': 'https://hh.ru/vacancy/73448242?from=vacancy_search_list&query=data+science'},
#  {'title': 'Специалист по Data Science',
#   'salary': '76\u202f967 – 76\u202f967 руб.',
#   'link': 'https://hh.ru/vacancy/67882937?from=vacancy_search_list&query=data+science'},
#  {'title': 'Middle/Senior Data Engineer',
#   'salary': 'от 200\u202f000 руб.',
#   'link': 'https://hh.ru/vacancy/71220088?from=vacancy_search_list&query=data+science'},
#  {'title': 'Junior Data Scientist в лабораторию кибербезопасности Сбера',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73996712?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Scientist / Аналитик Data Science',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/72819441?from=vacancy_search_list&query=data+science'},
#  {'title': 'Senior Data Scientist',
#   'salary': 'до 300\u202f000 руб.',
#   'link': 'https://hh.ru/vacancy/70168410?from=vacancy_search_list&query=data+science'},
#  {'title': 'ML Team Lead на продукт MTS Travel (Big Data)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/74099718?from=vacancy_search_list&query=data+science'},
#  {'title': 'Machine Learning Engineer',
#   'salary': '4\u202f000 – 8\u202f000 USD',
#   'link': 'https://hh.ru/vacancy/73889934?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data QA',
#   'salary': 'от 100\u202f000 руб.',
#   'link': 'https://hh.ru/vacancy/73392799?from=vacancy_search_list&query=data+science'},
#  {'title': 'Биоинформатик',
#   'salary': '60\u202f000 – 150\u202f000 руб.',
#   'link': 'https://hh.ru/vacancy/73724878?from=vacancy_search_list&query=data+science'},
#  {'title': 'Middle+/Senior Data Analyst',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73779126?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Scientist to Armenia',
#   'salary': 'до 5\u202f600 USD',
#   'link': 'https://hh.ru/vacancy/73824367?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Science',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/70674007?from=vacancy_search_list&query=data+science'},
#  {'title': 'Senior Python developer (MLOps)',
#   'salary': 'от 3\u202f500 EUR',
#   'link': 'https://hh.ru/vacancy/72696394?from=vacancy_search_list&query=data+science'},
#  {'title': 'Lead Data Scientist (booking platform)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/72663343?from=vacancy_search_list&query=data+science'},
#  {'title': 'Senior Data Engineer',
#   'salary': '250\u202f000 – 300\u202f000 руб.',
#   'link': 'https://hh.ru/vacancy/73453345?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Scientist Middle/Senior',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/71322369?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Scientist, Postdoctoral Research Assistant in Biomedical Statistics and Data Analysis',
#   'salary': '172\u202f000 – 276\u202f000 руб.',
#   'link': 'https://hh.ru/vacancy/73826298?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Science',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73859190?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data science',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73808705?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Analyst',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73862350?from=vacancy_search_list&query=data+science'},
#  {'title': 'Associate Professor - Data Science&AI',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73328680?from=vacancy_search_list&query=data+science'},
#  {'title': 'Антифрод аналитик (Риск-аналитик)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/74048590?from=vacancy_search_list&query=data+science'},
#  {'title': 'Power BI Developer',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/74091138?from=vacancy_search_list&query=data+science'},
#  {'title': 'Стажер Data scientist (Управление рисками корпоративных клиентов)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73814137?from=vacancy_search_list&query=data+science'},
#  {'title': 'Senior Data Scientist в направление продаж',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73060496?from=vacancy_search_list&query=data+science'},
#  {'title': 'Senior / Lead Data scientist',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/69404613?from=vacancy_search_list&query=data+science'},
#  {'title': 'Руководитель направления "Прогнозирование" (Data Science Team Lead)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73589242?from=vacancy_search_list&query=data+science'},
#  {'title': 'Аналитик (Data science)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73678767?from=vacancy_search_list&query=data+science'},
#  {'title': 'Начальник отдела моделирования и прогнозной аналитики (Риски)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73849498?from=vacancy_search_list&query=data+science'},
#  {'title': 'Associate Professor - Data Science&AI',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73328782?from=vacancy_search_list&query=data+science'},
#  {'title': 'Руководитель дирекции клиентской аналитики и математического моделирования',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73901496?from=vacancy_search_list&query=data+science'},
#  {'title': 'Инженер данных / Дата-инженер',
#   'salary': '120\u202f000 – 200\u202f000 руб.',
#   'link': 'https://hh.ru/vacancy/73411400?from=vacancy_search_list&query=data+science'},
#  {'title': 'Senior Data / ML Engineer (Персонализация)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/66550537?from=vacancy_search_list&query=data+science'},
#  {'title': 'Senior/Middle Python разработчик',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/72925976?from=vacancy_search_list&query=data+science'},
#  {'title': 'Data Scientist/Data Analyst',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73872513?from=vacancy_search_list&query=data+science'},
#  {'title': 'Team Lead Data Scientist',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/67136583?from=vacancy_search_list&query=data+science'},
#  {'title': 'Разработчик курса/методист/преподаватель по Data Science',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73357233?from=vacancy_search_list&query=data+science'},
#  {'title': 'Junior Data Scientist (Стажер)',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73222510?from=vacancy_search_list&query=data+science'},
#  {'title': 'Technical Project Manager',
#   'salary': 'з/п не указана',
#   'link': 'https://hh.ru/vacancy/73473192?from=vacancy_search_list&query=data+science'},
#  {'title': 'DevOps and Database engineer',
#   'salary': '4\u202f000 – 5\u202f000 EUR',
#   'link': 'https://hh.ru/vacancy/73702367?from=vacancy_search_list&query=data+science'}]

# %%
len(hh_list)
# Out:
# 60

# %%
hh_df = pd.DataFrame.from_dict(hh_list)

# %%
hh_df
# Out:
#                                                 title                  salary  \
# 0   NLP исследователь в группу AI в медицине Sber ...          з/п не указана
# 1        Python developer (Machine Learning Engineer)          з/п не указана
# 2                                       Data engineer          з/п не указана
# 3   Middle Data Science в лабораторию искусственно...          з/п не указана
# 4   NLP исследователь в группу AI в медицине Sber ...          з/п не указана
# 5        Python developer (Machine Learning Engineer)          з/п не указана
# 6                                       Data engineer          з/п не указана
# 7                                      Data Scientist          з/п не указана
# 8   Data scientist (Управление рисками корпоративн...          з/п не указана
# 9                                Middle Data Engineer          з/п не указана
# 10  Специалист по углубленной аналитике данных (Da...          з/п не указана
# 11  Middle продуктовый аналитик для продукта Talantix          з/п не указана
# 12                  Владелец моделей оценки рисков РБ          з/п не указана
# 13                  Владелец моделей оценки рисков РБ          з/п не указана
# 14                               Head of Data Science          з/п не указана
# 15                 Data Science (Компьютерное зрение)          з/п не указана
# 16                                      Data Engineer         от 300 000 руб.
# 17                                      Data Engineer         от 300 000 руб.
# 18                                     Data Scientist          з/п не указана
# 19                                      Data Engineer         от 230 000 руб.
# 20                         Специалист по Data Science    76 967 – 76 967 руб.
# 21                        Middle/Senior Data Engineer         от 200 000 руб.
# 22  Junior Data Scientist в лабораторию кибербезоп...          з/п не указана
# 23             Data Scientist / Аналитик Data Science          з/п не указана
# 24                              Senior Data Scientist         до 300 000 руб.
# 25      ML Team Lead на продукт MTS Travel (Big Data)          з/п не указана
# 26                          Machine Learning Engineer       4 000 – 8 000 USD
# 27                                            Data QA         от 100 000 руб.
# 28                                      Биоинформатик   60 000 – 150 000 руб.
# 29                        Middle+/Senior Data Analyst          з/п не указана
# 30                          Data Scientist to Armenia            до 5 600 USD
# 31                                       Data Science          з/п не указана
# 32                    Senior Python developer (MLOps)            от 3 500 EUR
# 33             Lead Data Scientist (booking platform)          з/п не указана
# 34                               Senior Data Engineer  250 000 – 300 000 руб.
# 35                       Data Scientist Middle/Senior          з/п не указана
# 36  Data Scientist, Postdoctoral Research Assistan...  172 000 – 276 000 руб.
# 37                                       Data Science          з/п не указана
# 38                                       Data science          з/п не указана
# 39                                       Data Analyst          з/п не указана
# 40              Associate Professor - Data Science&AI          з/п не указана
# 41                  Антифрод аналитик (Риск-аналитик)          з/п не указана
# 42                                 Power BI Developer          з/п не указана
# 43  Стажер Data scientist (Управление рисками корп...          з/п не указана
# 44         Senior Data Scientist в направление продаж          з/п не указана
# 45                       Senior / Lead Data scientist          з/п не указана
# 46  Руководитель направления "Прогнозирование" (Da...          з/п не указана
# 47                            Аналитик (Data science)          з/п не указана
# 48  Начальник отдела моделирования и прогнозной ан...          з/п не указана
# 49              Associate Professor - Data Science&AI          з/п не указана
# 50  Руководитель дирекции клиентской аналитики и м...          з/п не указана
# 51                      Инженер данных / Дата-инженер  120 000 – 200 000 руб.
# 52         Senior Data / ML Engineer (Персонализация)          з/п не указана
# 53                   Senior/Middle Python разработчик          з/п не указана
# 54                        Data Scientist/Data Analyst          з/п не указана
# 55                           Team Lead Data Scientist          з/п не указана
# 56  Разработчик курса/методист/преподаватель по Da...          з/п не указана
# 57                     Junior Data Scientist (Стажер)          з/п не указана
# 58                          Technical Project Manager          з/п не указана
# 59                       DevOps and Database engineer       4 000 – 5 000 EUR
#
#                                                  link
# 0   https://hh.ru/vacancy/73469286?from=vacancy_se...
# 1   https://hh.ru/vacancy/73468878?from=vacancy_se...
# 2   https://hh.ru/vacancy/73471184?from=vacancy_se...
# 3   https://hh.ru/vacancy/72747471?from=vacancy_se...
# 4   https://hh.ru/vacancy/72798521?from=vacancy_se...
# 5   https://hh.ru/vacancy/72074865?from=vacancy_se...
# 6   https://hh.ru/vacancy/72030869?from=vacancy_se...
# 7   https://hh.ru/vacancy/69162481?from=vacancy_se...
# 8   https://hh.ru/vacancy/72421275?from=vacancy_se...
# 9   https://hh.ru/vacancy/73751663?from=vacancy_se...
# 10  https://hh.ru/vacancy/72920605?from=vacancy_se...
# 11  https://hh.ru/vacancy/72468896?from=vacancy_se...
# 12  https://hh.ru/vacancy/73470798?from=vacancy_se...
# 13  https://hh.ru/vacancy/72285480?from=vacancy_se...
# 14  https://hh.ru/vacancy/74150096?from=vacancy_se...
